# %%
from PIL import Image,ImageFilter,ImageFont,ImageDraw

# %%
img=Image.open('HIMYM.jpg')

# %%
img.format
# Out:
# 'JPEG'

# %%
img.mode
# Out:
# 'RGB'

# %%
img.bits
# Out:
# 8

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=210x239 at 0x2D8DBF5F7F0>

# %%
img2=Image.open("hIMYM2.jpg")

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x2D8DBEBEC40>

# %%
img2.height
# Out:
# 300

# %%
img2.crop((0,0,300,200))
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2D8DBF85340>

# %%
img3=Image.open('googleads.png')

# %%
img.size
# Out:
# (210, 239)

# %%
img3.crop((0,210,210,239))
# Out:
# <PIL.Image.Image image mode=RGBA size=210x29 at 0x2D8DBEBEFD0>

# %%
image=Image.open('msft.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=420x420 at 0x2D8D599CCA0>

# %%
image.filter(ImageFilter.CONTOUR())
# Out:
# <PIL.Image.Image image mode=RGB size=420x420 at 0x2D8DBF85B50>

# %%
image.filter(ImageFilter.EDGE_ENHANCE())
# Out:
# <PIL.Image.Image image mode=RGB size=420x420 at 0x2D8DBF5F3A0>

# %%
image.filter(ImageFilter.EMBOSS())
# Out:
# <PIL.Image.Image image mode=RGB size=420x420 at 0x2D8D59C4E20>

# %%
r,g,b=image.split()

# %%
r
# Out:
# <PIL.Image.Image image mode=L size=420x420 at 0x2D8DBF957C0>

# %%
g
# Out:
# <PIL.Image.Image image mode=L size=420x420 at 0x2D8DBF95820>

# %%
b
# Out:
# <PIL.Image.Image image mode=L size=420x420 at 0x2D8DBF95D00>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=210x239 at 0x2D8D599C130>

# %%
img5=Image.open('vscode.jpeg')

# %%
img5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=266x190 at 0x2D8DBF95970>

# %%
image.paste(img5)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=420x420 at 0x2D8D599CCA0>

# %%
font=ImageFont.truetype('RobotoMono-VariableFont_wght.ttf',5)
writer=ImageDraw.Draw(image)
writer.text((300,300),"Rahul Khattri",font=font,fill=(225,0,0))

# %%
image.size
# Out:
# (420, 420)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=420x420 at 0x2D8D599CCA0>
